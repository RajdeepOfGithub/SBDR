# %%
pwd
# Out:
# '/Users/rajdeeproy/UMBC/ObsidianVaults/Interview Prep/Projects/SBDR/notebooks'

# %%
ls
# Out:
# 01_data_loading.ipynb         04_feature_engineering.ipynb
# 02_remaining_datasets.ipynb   05_synthetic_chats.ipynb
# 03_dataset_merge.ipynb        Testing Dataset.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/sbdr_final_dataset.csv")

# %%
df.shape
# Out:
# (30000, 88)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  inquiry_x_delay  accounts_x_util  fraud_x_delinquency  \
# 0     -2  ...        -0.234265         0.677121             0.007296
# 1      0  ...         0.549224         0.373163             0.000000
# 2      0  ...         0.000000         1.670667             0.000000
# 3      0  ...         0.000000        10.688529             0.000000
# 4      0  ...        -0.190202         4.389607             0.000000
#
#    distress_encoded  pb_label_encoded  mh_status_encoded  sp_category_freq  \
# ...

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'spending_volatility', 'pay_ratio_1',
#        'pay_ratio_2', 'pay_ratio_3', 'pay_ratio_4', 'pay_ratio_5',
#        'pay_ratio_6', 'delinq_accel', 'customer_id', 'avg_pay_delay',
#        'distress_level', 'lc_loan_amnt_mean', 'lc_funded_amnt_mean',
#        'lc_annual_inc_mean', 'lc_dti_mean', 'lc_revol_util_mean',
#        'lc_delinq_2yrs_mean', 'lc_inq_last_6mths_mean', 'lc_open_acc_mean',
#        'lc_pub_rec_mean', 'lc_total_acc_mean', 'lc_installment_mean',
#        'lc_int_rate_mean', 'sp_total_spend', 'sp_avg_monthly_spend',
#        'sp_spend_volatility', 'sp_num_transactions', 'sp_top_category',
# ...
